# %% [markdown]
# # Galaxy Classification using SDSS-like Dataset
#
# This notebook is a starter analysis companion for the main training pipeline in `src/train.py`.

# %%
from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

DATA_PATH = Path('../data/sdss_galaxy_data.csv')
df = pd.read_csv(DATA_PATH)
df.head()

# %%
df.info()
df.describe()

# %%
sns.countplot(data=df, x='class')
plt.title('Class Distribution')
plt.show()
